# %% [markdown]
# # Word-Level Force Alignment Tutorial
#
# This beginner-friendly tutorial will show you how to align words in a transcript with their exact timestamps in an audio recording using wav2vec.

# %% [markdown]
# ## 1. What is Force Alignment?
#
# Force alignment is a technique that automatically maps words in a transcript to their exact timestamps in an audio recording. Think of it as creating a precise timeline of when each word was spoken.
#
# In simple terms, force alignment takes:
# - An audio recording
# - A text transcript of what was said
#
# And it tells you exactly when each word starts and ends in the audio.
#
# For example, if you have an audio recording saying "Hello, how are you today?" and the corresponding text, force alignment would tell you that:
# - "Hello" occurs from 0.2 to 0.5 seconds
# - "how" occurs from 0.6 to 0.8 seconds
# - "are" occurs from 0.9 to 1.0 seconds
# - "you" occurs from 1.1 to 1.3 seconds
# - "today" occurs from 1.4 to 1.8 seconds
#
# This timestamp information is incredibly valuable for many applications, especially when working with media content.

# %% [markdown]
# ## 1. Why is Force Alignment Useful?
#
# Force alignment has several practical applications in media production:
#
# - **Subtitles and Captions**: Creates perfectly timed subtitles that appear exactly when words are spoken
# - **Video Editing**: Quickly locate specific spoken phrases in long recordings
# - **Dubbing and Voice-overs**: Match new audio to original timing for natural-sounding dubs
# - **Language Learning**: Create interactive materials where students can click on words to hear pronunciation
#
# In this tutorial, we'll focus on creating an interactive visualization where you can click on words to hear them played back.

# %% [markdown]
# ## 3. Setup
#
# First, let's install the necessary libraries. Run this cell if you haven't installed these packages yet.

# %%
# run if needed
# !pip install torch torchaudio transformers matplotlib librosa ipywidgets
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (7.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.7.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.7)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 28.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jedi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:

# %% [markdown]
# ## 4. Preparing the Audio and Transcript
#
# For this tutorial, we'll use a short Arabic audio sample with its corresponding transcript.

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import re
import librosa
import librosa.display
import IPython.display as ipd
from ipywidgets import Button, HBox, VBox, Layout, Output
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import json

# Set up matplotlib for Arabic text
plt.rcParams['font.family'] = ['DejaVu Sans', 'sans-serif']

# Function to split Arabic text into words
def split_arabic_text(text):
    # Split by whitespace while preserving Arabic characters
    words = re.split(r'\s+', text.strip())
    return [word for word in words if word]  # Remove any empty strings

# %%
# Load the audio file and transcript
# Note: Replace with your own audio and transcript files
audio_path = "sample_data/arabic_sample.wav"
transcript_path = "sample_data/arabic_transcript.txt"

# Read the transcript and split into words
with open(transcript_path, 'r', encoding='utf-8') as f:
    transcript = f.read().strip()

words = split_arabic_text(transcript)
print(f"Transcript: {transcript}")
print(f"Words ({len(words)}): {words}")

# Load and display the audio
y, sr = librosa.load(audio_path)
ipd.Audio(y, rate=sr)
# Out:
# Transcript: هذا الشارع سوي لممارسه رياضه الركض يوميا و لم التقي باي شخص علي الاطلاق
# Words (14): ['هذا', 'الشارع', 'سوي', 'لممارسه', 'رياضه', 'الركض', 'يوميا', 'و', 'لم', 'التقي', 'باي', 'شخص', 'علي', 'الاطلاق']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 5. Visualize the Audio Waveform
#
# Let's look at the audio waveform to get a better understanding of our data.

# %%
plt.figure(figsize=(10, 3))
librosa.display.waveshow(y, sr=sr)
plt.title('Audio Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Word-Level Force Alignment with Wav2Vec
#
# Now, let's perform word-level force alignment using the wav2vec model.

# %%
# Load pre-trained model and processor for Arabic
model_name = "jonatasgrosman/wav2vec2-large-xlsr-53-arabic"
processor = Wav2Vec2Processor.from_pretrained(model_name)
model = Wav2Vec2ForCTC.from_pretrained(model_name)

# Load the audio with torchaudio for processing
waveform, sample_rate = torchaudio.load(audio_path)
if waveform.shape[0] > 1:
    waveform = torch.mean(waveform, dim=0, keepdim=True)

# Resample (wav2vec2 expects 16kHz)
if sample_rate != 16000:
    resampler = torchaudio.transforms.Resample(sample_rate, 16000)
    waveform = resampler(waveform)
    sample_rate = 16000

# Convert audio to features
input_values = processor(waveform.squeeze().numpy(), sampling_rate=sample_rate, return_tensors="pt").input_values

# Get the CTC probabilities (it gives series of characters predictions)
with torch.no_grad():
    logits = model(input_values).logits

# Get the probability matrix
probs = torch.nn.functional.softmax(logits, dim=-1)
probs = probs.squeeze().detach().cpu()
print(probs.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py:311: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# torch.Size([419, 51])

# %% [markdown]
# **`probs.shape`** returns a shape of **`(419, 51)`**.
# This means there are 419 frames, where each frame represents 20 milliseconds of audio.
#
# For every 20 ms segment, the model outputs a probability vector of size 51, corresponding to the likelihoods of 51 possible character predictions — such as ألف، باء، تاء and so on.

# %% [markdown]
# To understand which index corresponds to which character, we retrieve the vocabulary using `processor.tokenizer.get_vocab()`.
#
# This allows us to interpret the output probabilities by mapping each index in the vector to its corresponding Arabic character or special symbol.

# %%
# Get the character mapping
vocab = processor.tokenizer.get_vocab()
id_to_char = {v: k for k, v in vocab.items()}
print(id_to_char)
# Out:
# {0: '<pad>', 1: '<s>', 2: '</s>', 3: '<unk>', 4: '|', 5: '-', 6: 'ء', 7: 'آ', 8: 'أ', 9: 'ؤ', 10: 'إ', 11: 'ئ', 12: 'ا', 13: 'ب', 14: 'ة', 15: 'ت', 16: 'ث', 17: 'ج', 18: 'ح', 19: 'خ', 20: 'د', 21: 'ذ', 22: 'ر', 23: 'ز', 24: 'س', 25: 'ش', 26: 'ص', 27: 'ض', 28: 'ط', 29: 'ظ', 30: 'ع', 31: 'غ', 32: 'ـ', 33: 'ف', 34: 'ق', 35: 'ك', 36: 'ل', 37: 'م', 38: 'ن', 39: 'ه', 40: 'و', 41: 'ى', 42: 'ي', 43: 'ً', 44: 'ٌ', 45: 'ٍ', 46: 'َ', 47: 'ُ', 48: 'ِ', 49: 'ّ', 50: 'ْ'}

# %% [markdown]
# Let's now use the probability matrix to get the alignmnet for each characters.

# %% [markdown]
# ## 7. Alignment Probability -- Trellis
#
# From the emission matrix, we generate the **trellis**, which represents the probability accumulations of transcript labels at each time frame.
#
# The trellis is a 2D matrix with
# - **time axis** indexed by `t`
# - **label axis** indexed by `j`, representing the transcript labels

# %%
def get_trellis(emission, tokens, blank_id=0):
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    trellis = torch.zeros((num_frame, num_tokens))
    trellis[1:, 0] = torch.cumsum(emission[1:, blank_id], 0)
    trellis[0, 1:] = -float("inf")
    trellis[-num_tokens + 1 :, 0] = float("inf")

    for t in range(num_frame - 1):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens[1:]],)
    return trellis

# let's tokenize our sentence:
sentence="هذا الشارع سوي لممارسه رياضه الركض يوميا و لم التقي باي شخص علي الاطلاق"
tokens = processor.tokenizer(sentence, add_special_tokens=False).input_ids

# let's get trellis
trellis = get_trellis(probs, tokens)

# %% [markdown]
# ## 8. Find the most likely path (backtracking)
#
# Once the trellis is generated, we will traverse it following the elements with high probability. => this is called backtracking

# %%
from dataclasses import dataclass

@dataclass
class Point:
    token_index: int
    time_index: int
    score: float

## Based ion Viterbi optimization
def backtrack(trellis, emission, tokens, blank_id=0):
    t, j = trellis.size(0) - 1, trellis.size(1) - 1

    path = [Point(j, t, emission[t, blank_id].exp().item())]
    while j > 0:
        # Should not happen but just in case
        assert t > 0

        # 1. Figure out if the current position was stay or change
        # Frame-wise score of stay vs change
        p_stay = emission[t - 1, blank_id]
        p_change = emission[t - 1, tokens[j]]

        # Context-aware score for stay vs change
        stayed = trellis[t - 1, j] + p_stay
        changed = trellis[t - 1, j - 1] + p_change

        # Update position
        t -= 1
        if changed > stayed:
            j -= 1

        # Store the path with frame-wise probability.
        prob = (p_change if changed > stayed else p_stay).exp().item()
        path.append(Point(j, t, prob))

    # Now j == 0, which means, it reached the SoS.
    # Fill up the rest for the sake of visualization
    while t > 0:
        prob = emission[t - 1, blank_id].exp().item()
        path.append(Point(j, t - 1, prob))
        t -= 1

    return path[::-1]


path = backtrack(trellis, probs, tokens)
for p in path:
    print(p)
# Out:
# Point(token_index=0, time_index=0, score=2.7182013988494873)
# Point(token_index=0, time_index=1, score=2.718154191970825)
# Point(token_index=0, time_index=2, score=2.7181615829467773)
# Point(token_index=0, time_index=3, score=2.7181756496429443)
# Point(token_index=0, time_index=4, score=2.7182092666625977)
# Point(token_index=0, time_index=5, score=2.718273639678955)
# Point(token_index=0, time_index=6, score=2.7182457447052)
# Point(token_index=0, time_index=7, score=2.7182490825653076)
# Point(token_index=0, time_index=8, score=2.7182791233062744)
# Point(token_index=0, time_index=9, score=2.71828031539917)
# Point(token_index=0, time_index=10, score=2.718280553817749)
# Point(token_index=0, time_index=11, score=2.718280553817749)
# Point(token_index=0, time_index=12, score=2.71828031539917)
# Point(token_index=0, time_index=13, score=2.718276262283325)
# Point(token_index=0, time_index=14, score=2.7182457447052)
# Point(token_index=0, time_index=15, score=2.718266248703003)
# Point(token_index=0, time_index=16, score=2.718278646469116)
# Point(token_index=0, time_index=17, score=2.7182745933532715)
# Point(token_index=0, time_index=18, score=2.7181897163391113)
# Point(token_index=0, time_index=19, score=2.7136638164520264)
# Point(token_index=0, time_index=20, score=2.6719532012939453)
# Point(token_index=0, time_index=21, score=2.6529438495635986)
# Point(token_index=0, time_index=22, score=2.707385301589966)
# Point(token_index=0, time_index=23, score=2.7161943912506104)
# Point(token_index=0, time_index=24, score=2.7179205417633057)
# Point(token_index=0, time_index=25, score=2.7129690647125244)
# Point(token_index=0, time_index=26, score=1.0000067949295044)
# Point(token_index=0, time_index=27, score=2.7182812690734863)
# Point(token_index=0, time_index=28, score=2.718277931213379)
# Point(token_index=0, time_index=29, score=2.7182650566101074)
# Point(token_index=0, time_index=30, score=2.718266487121582)
# Point(token_index=0, time_index=31, score=2.7182750701904297)
# Point(token_index=0, time_index=32, score=2.718280553817749)
# Point(token_index=0, time_index=33, score=2.718280792236328)
# Point(token_index=0, time_index=34, score=2.718275785446167)
# Point(token_index=0, time_index=35, score=2.703577995300293)
# Point(token_index=1, time_index=36, score=2.71828031539917)
# Point(token_index=1, time_index=37, score=2.715128183364868)
# Point(token_index=1, time_index=38, score=2.718212127685547)
# Point(token_index=2, time_index=39, score=1.2453404664993286)
# Point(token_index=2, time_index=40, score=2.4108152389526367)
# Point(token_index=2, time_index=41, score=1.1026681661605835)
# Point(token_index=2, time_index=42, score=2.6426587104797363)
# Point(token_index=3, time_index=43, score=1.0938130617141724)
# Point(token_index=3, time_index=44, score=2.711630344390869)
# Point(token_index=3, time_index=45, score=1.1327874660491943)
# Point(token_index=3, time_index=46, score=2.714920997619629)
# Point(token_index=4, time_index=47, score=1.9177182912826538)
# Point(token_index=4, time_index=48, score=2.7176520824432373)
# Point(token_index=5, time_index=49, score=2.706037998199463)
# Point(token_index=5, time_index=50, score=2.7182724475860596)
# Point(token_index=5, time_index=51, score=2.7182812690734863)
# Point(token_index=5, time_index=52, score=2.7182509899139404)
# Point(token_index=6, time_index=53, score=2.7179577350616455)
# Point(token_index=6, time_index=54, score=2.71822452545166)
# Point(token_index=6, time_index=55, score=2.718268871307373)
# Point(token_index=6, time_index=56, score=2.71828031539917)
# Point(token_index=6, time_index=57, score=2.7181525230407715)
# Point(token_index=6, time_index=58, score=2.718263626098633)
# Point(token_index=7, time_index=59, score=2.7107014656066895)
# Point(token_index=7, time_index=60, score=2.7182650566101074)
# Point(token_index=7, time_index=61, score=2.7182185649871826)
# Point(token_index=7, time_index=62, score=2.7181901931762695)
# Point(token_index=8, time_index=63, score=1.0222227573394775)
# Point(token_index=8, time_index=64, score=2.7177798748016357)
# Point(token_index=8, time_index=65, score=2.7181856632232666)
# Point(token_index=8, time_index=66, score=2.7182655334472656)
# Point(token_index=8, time_index=67, score=2.7180190086364746)
# Point(token_index=8, time_index=68, score=2.7182514667510986)
# Point(token_index=9, time_index=69, score=2.3951895236968994)
# Point(token_index=9, time_index=70, score=1.048210859298706)
# Point(token_index=9, time_index=71, score=2.717254877090454)
# Point(token_index=10, time_index=72, score=1.0033725500106812)
# Point(token_index=10, time_index=73, score=1.0003565549850464)
# Point(token_index=10, time_index=74, score=2.402480125427246)
# Point(token_index=10, time_index=75, score=1.000977873802185)
# Point(token_index=10, time_index=76, score=1.8677287101745605)
# Point(token_index=10, time_index=77, score=2.7181994915008545)
# Point(token_index=10, time_index=78, score=2.7182679176330566)
# Point(token_index=10, time_index=79, score=1.4966273307800293)
# Point(token_index=11, time_index=80, score=2.7117741107940674)
# Point(token_index=11, time_index=81, score=2.714568614959717)
# Point(token_index=11, time_index=82, score=2.7182536125183105)
# Point(token_index=11, time_index=83, score=2.7182483673095703)
# Point(token_index=11, time_index=84, score=2.7182438373565674)
# Point(token_index=11, time_index=85, score=2.718212366104126)
# Point(token_index=11, time_index=86, score=2.7181336879730225)
# Point(token_index=12, time_index=87, score=2.718269109725952)
# Point(token_index=12, time_index=88, score=2.7182788848876953)
# Point(token_index=12, time_index=89, score=2.7182562351226807)
# Point(token_index=12, time_index=90, score=1.0000044107437134)
# Point(token_index=13, time_index=91, score=1.00003981590271)
# Point(token_index=14, time_index=92, score=2.718165159225464)
# Point(token_index=14, time_index=93, score=2.6795601844787598)
# Point(token_index=14, time_index=94, score=2.603119373321533)
# Point(token_index=14, time_index=95, score=2.712725877761841)
# Point(token_index=15, time_index=96, score=1.3489630222320557)
# Point(token_index=15, time_index=97, score=1.4695695638656616)
# Point(token_index=15, time_index=98, score=1.637667179107666)
# Point(token_index=15, time_index=99, score=2.524077892303467)
# Point(token_index=15, time_index=100, score=2.708775520324707)
# Point(token_index=15, time_index=101, score=2.716742515563965)
# Point(token_index=15, time_index=102, score=2.7182135581970215)
# Point(token_index=16, time_index=103, score=2.718247890472412)
# Point(token_index=16, time_index=104, score=2.7181849479675293)
# Point(token_index=16, time_index=105, score=2.718196392059326)
# Point(token_index=16, time_index=106, score=2.7182796001434326)
# Point(token_index=16, time_index=107, score=2.7178537845611572)
# Point(token_index=17, time_index=108, score=2.718271493911743)
# Point(token_index=17, time_index=109, score=2.7182791233062744)
# Point(token_index=17, time_index=110, score=2.718271017074585)
# Point(token_index=17, time_index=111, score=1.1186323165893555)
# Point(token_index=17, time_index=112, score=2.718240976333618)
# Point(token_index=18, time_index=113, score=2.7181055545806885)
# Point(token_index=18, time_index=114, score=2.7182798385620117)
# Point(token_index=18, time_index=115, score=2.7182114124298096)
# Point(token_index=19, time_index=116, score=2.717636823654175)
# Point(token_index=19, time_index=117, score=2.718268632888794)
# Point(token_index=19, time_index=118, score=2.718276023864746)
# Point(token_index=19, time_index=119, score=2.718264102935791)
# Point(token_index=19, time_index=120, score=2.7182705402374268)
# Point(token_index=19, time_index=121, score=1.0000277757644653)
# Point(token_index=20, time_index=122, score=2.718254327774048)
# Point(token_index=20, time_index=123, score=2.71821665763855)
# Point(token_index=20, time_index=124, score=2.7180607318878174)
# Point(token_index=20, time_index=125, score=2.717827796936035)
# Point(token_index=20, time_index=126, score=2.713705062866211)
# Point(token_index=20, time_index=127, score=1.000024676322937)
# Point(token_index=21, time_index=128, score=1.3855996131896973)
# Point(token_index=21, time_index=129, score=2.4844729900360107)
# Point(token_index=22, time_index=130, score=1.2158336639404297)
# Point(token_index=22, time_index=131, score=2.1784417629241943)
# Point(token_index=23, time_index=132, score=2.6066033840179443)
# Point(token_index=23, time_index=133, score=2.6384117603302)
# Point(token_index=23, time_index=134, score=2.7112503051757812)
# Point(token_index=23, time_index=135, score=2.7084860801696777)
# Point(token_index=24, time_index=136, score=2.718250036239624)
# Point(token_index=24, time_index=137, score=2.7182457447052)
# Point(token_index=24, time_index=138, score=2.718210458755493)
# Point(token_index=24, time_index=139, score=2.7122747898101807)
# Point(token_index=25, time_index=140, score=2.717414379119873)
# Point(token_index=25, time_index=141, score=2.7182042598724365)
# Point(token_index=25, time_index=142, score=2.7181966304779053)
# Point(token_index=25, time_index=143, score=1.78919517993927)
# Point(token_index=26, time_index=144, score=2.7161171436309814)
# Point(token_index=26, time_index=145, score=2.717454433441162)
# Point(token_index=26, time_index=146, score=2.7173030376434326)
# Point(token_index=26, time_index=147, score=2.718003511428833)
# Point(token_index=26, time_index=148, score=2.7163431644439697)
# Point(token_index=26, time_index=149, score=1.0007902383804321)
# Point(token_index=27, time_index=150, score=1.9660913944244385)
# Point(token_index=27, time_index=151, score=1.6026825904846191)
# Point(token_index=27, time_index=152, score=2.273038148880005)
# Point(token_index=28, time_index=153, score=2.3527936935424805)
# Point(token_index=28, time_index=154, score=2.7051191329956055)
# Point(token_index=28, time_index=155, score=2.6735048294067383)
# Point(token_index=29, time_index=156, score=1.0408130884170532)
# Point(token_index=29, time_index=157, score=1.0067341327667236)
# Point(token_index=29, time_index=158, score=2.714254140853882)
# Point(token_index=30, time_index=159, score=2.7145090103149414)
# Point(token_index=30, time_index=160, score=2.7181897163391113)
# Point(token_index=31, time_index=161, score=2.2869503498077393)
# Point(token_index=31, time_index=162, score=2.718085765838623)
# Point(token_index=31, time_index=163, score=2.718252658843994)
# Point(token_index=31, time_index=164, score=2.718118906021118)
# Point(token_index=31, time_index=165, score=2.717740535736084)
# Point(token_index=31, time_index=166, score=2.7182767391204834)
# Point(token_index=31, time_index=167, score=2.7182788848876953)
# Point(token_index=31, time_index=168, score=2.7167720794677734)
# Point(token_index=32, time_index=169, score=2.7161288261413574)
# Point(token_index=32, time_index=170, score=2.710570812225342)
# Point(token_index=32, time_index=171, score=2.7143609523773193)
# Point(token_index=32, time_index=172, score=2.717813730239868)
# Point(token_index=32, time_index=173, score=2.718212842941284)
# Point(token_index=32, time_index=174, score=2.7182633876800537)
# Point(token_index=32, time_index=175, score=1.0847007036209106)
# Point(token_index=33, time_index=176, score=2.565143346786499)
# Point(token_index=33, time_index=177, score=2.0127880573272705)
# Point(token_index=33, time_index=178, score=2.2645492553710938)
# Point(token_index=33, time_index=179, score=1.689083456993103)
# Point(token_index=33, time_index=180, score=2.5344595909118652)
# Point(token_index=34, time_index=181, score=1.12957763671875)
# Point(token_index=34, time_index=182, score=2.021517038345337)
# Point(token_index=34, time_index=183, score=2.7156155109405518)
# Point(token_index=34, time_index=184, score=2.718066930770874)
# Point(token_index=35, time_index=185, score=2.7182724475860596)
# Point(token_index=35, time_index=186, score=2.717165231704712)
# Point(token_index=35, time_index=187, score=2.7174038887023926)
# Point(token_index=35, time_index=188, score=2.2393722534179688)
# Point(token_index=35, time_index=189, score=2.7182464599609375)
# Point(token_index=36, time_index=190, score=2.718125343322754)
# Point(token_index=36, time_index=191, score=2.7182788848876953)
# Point(token_index=36, time_index=192, score=2.718280792236328)
# Point(token_index=36, time_index=193, score=2.718243360519409)
# Point(token_index=37, time_index=194, score=2.718277931213379)
# Point(token_index=37, time_index=195, score=2.718277931213379)
# Point(token_index=37, time_index=196, score=2.718276262283325)
# Point(token_index=37, time_index=197, score=2.7182772159576416)
# Point(token_index=37, time_index=198, score=2.718273162841797)
# Point(token_index=37, time_index=199, score=2.716944932937622)
# Point(token_index=38, time_index=200, score=2.718276023864746)
# Point(token_index=38, time_index=201, score=2.718160390853882)
# Point(token_index=38, time_index=202, score=2.713209629058838)
# Point(token_index=38, time_index=203, score=2.0463476181030273)
# Point(token_index=39, time_index=204, score=1.0581034421920776)
# Point(token_index=39, time_index=205, score=2.1702630519866943)
# Point(token_index=39, time_index=206, score=1.2367398738861084)
# Point(token_index=39, time_index=207, score=1.0621747970581055)
# Point(token_index=39, time_index=208, score=2.700546979904175)
# Point(token_index=39, time_index=209, score=2.7131447792053223)
# Point(token_index=39, time_index=210, score=2.7181811332702637)
# Point(token_index=39, time_index=211, score=2.7182352542877197)
# Point(token_index=39, time_index=212, score=2.718144655227661)
# Point(token_index=39, time_index=213, score=2.718228340148926)
# Point(token_index=39, time_index=214, score=2.7182371616363525)
# Point(token_index=39, time_index=215, score=2.717916250228882)
# Point(token_index=39, time_index=216, score=2.715789556503296)
# Point(token_index=39, time_index=217, score=2.6890859603881836)
# Point(token_index=39, time_index=218, score=2.0983762741088867)
# Point(token_index=39, time_index=219, score=1.208669662475586)
# Point(token_index=39, time_index=220, score=1.0644941329956055)
# Point(token_index=39, time_index=221, score=2.583144426345825)
# Point(token_index=40, time_index=222, score=1.071110486984253)
# Point(token_index=40, time_index=223, score=1.7864538431167603)
# Point(token_index=40, time_index=224, score=2.717808961868286)
# Point(token_index=40, time_index=225, score=2.718228578567505)
# Point(token_index=41, time_index=226, score=1.097152829170227)
# Point(token_index=41, time_index=227, score=2.7121949195861816)
# Point(token_index=42, time_index=228, score=1.0123255252838135)
# Point(token_index=42, time_index=229, score=2.7181174755096436)
# Point(token_index=42, time_index=230, score=2.718269109725952)
# Point(token_index=43, time_index=231, score=2.7098844051361084)
# Point(token_index=43, time_index=232, score=2.7182767391204834)
# Point(token_index=43, time_index=233, score=2.7182745933532715)
# Point(token_index=43, time_index=234, score=2.7182798385620117)
# Point(token_index=43, time_index=235, score=2.718264102935791)
# Point(token_index=44, time_index=236, score=2.7178385257720947)
# Point(token_index=44, time_index=237, score=1.0000380277633667)
# Point(token_index=44, time_index=238, score=2.7182321548461914)
# Point(token_index=45, time_index=239, score=1.9703819751739502)
# Point(token_index=45, time_index=240, score=1.0021140575408936)
# Point(token_index=46, time_index=241, score=2.718278646469116)
# Point(token_index=46, time_index=242, score=2.718280553817749)
# Point(token_index=46, time_index=243, score=2.718278169631958)
# Point(token_index=46, time_index=244, score=2.7173235416412354)
# Point(token_index=46, time_index=245, score=2.718244791030884)
# Point(token_index=47, time_index=246, score=2.7182681560516357)
# Point(token_index=47, time_index=247, score=2.718275785446167)
# Point(token_index=47, time_index=248, score=2.7182669639587402)
# Point(token_index=47, time_index=249, score=2.7182090282440186)
# Point(token_index=47, time_index=250, score=2.718197822570801)
# Point(token_index=48, time_index=251, score=2.718278646469116)
# Point(token_index=48, time_index=252, score=2.71828031539917)
# Point(token_index=48, time_index=253, score=2.718280792236328)
# Point(token_index=48, time_index=254, score=2.7182815074920654)
# Point(token_index=48, time_index=255, score=2.718280792236328)
# Point(token_index=48, time_index=256, score=2.7182798385620117)
# Point(token_index=48, time_index=257, score=2.7182276248931885)
# Point(token_index=48, time_index=258, score=2.7181711196899414)
# Point(token_index=49, time_index=259, score=2.691378116607666)
# Point(token_index=49, time_index=260, score=2.710106134414673)
# Point(token_index=49, time_index=261, score=2.7147302627563477)
# Point(token_index=49, time_index=262, score=2.7144689559936523)
# Point(token_index=49, time_index=263, score=1.0000956058502197)
# Point(token_index=50, time_index=264, score=2.67924165725708)
# Point(token_index=50, time_index=265, score=2.7153398990631104)
# Point(token_index=50, time_index=266, score=2.6015467643737793)
# Point(token_index=50, time_index=267, score=2.2852351665496826)
# Point(token_index=50, time_index=268, score=2.080296516418457)
# Point(token_index=50, time_index=269, score=2.247697353363037)
# Point(token_index=50, time_index=270, score=2.3920223712921143)
# Point(token_index=50, time_index=271, score=2.6577682495117188)
# Point(token_index=50, time_index=272, score=2.6931254863739014)
# Point(token_index=50, time_index=273, score=2.714226007461548)
# Point(token_index=50, time_index=274, score=2.7165751457214355)
# Point(token_index=50, time_index=275, score=2.716522455215454)
# Point(token_index=50, time_index=276, score=2.7120773792266846)
# Point(token_index=50, time_index=277, score=2.7101240158081055)
# Point(token_index=50, time_index=278, score=2.698090076446533)
# Point(token_index=50, time_index=279, score=2.696864366531372)
# Point(token_index=50, time_index=280, score=2.5153775215148926)
# Point(token_index=50, time_index=281, score=1.027899146080017)
# Point(token_index=50, time_index=282, score=2.709704637527466)
# Point(token_index=51, time_index=283, score=1.1135969161987305)
# Point(token_index=51, time_index=284, score=2.7181239128112793)
# Point(token_index=51, time_index=285, score=2.718256950378418)
# Point(token_index=51, time_index=286, score=2.718210458755493)
# Point(token_index=51, time_index=287, score=1.809338927268982)
# Point(token_index=52, time_index=288, score=2.7180263996124268)
# Point(token_index=52, time_index=289, score=2.7106754779815674)
# Point(token_index=52, time_index=290, score=2.704603910446167)
# Point(token_index=52, time_index=291, score=2.673089027404785)
# Point(token_index=52, time_index=292, score=2.6058335304260254)
# Point(token_index=52, time_index=293, score=2.714245557785034)
# Point(token_index=52, time_index=294, score=2.7182552814483643)
# Point(token_index=52, time_index=295, score=1.000085473060608)
# Point(token_index=53, time_index=296, score=2.718271493911743)
# Point(token_index=53, time_index=297, score=2.718280792236328)
# Point(token_index=53, time_index=298, score=2.7182812690734863)
# Point(token_index=53, time_index=299, score=2.71828031539917)
# Point(token_index=53, time_index=300, score=2.7179481983184814)
# Point(token_index=53, time_index=301, score=2.7182445526123047)
# Point(token_index=54, time_index=302, score=2.7174065113067627)
# Point(token_index=54, time_index=303, score=2.7182247638702393)
# Point(token_index=54, time_index=304, score=2.715097188949585)
# Point(token_index=54, time_index=305, score=2.718275308609009)
# Point(token_index=55, time_index=306, score=1.0332448482513428)
# Point(token_index=55, time_index=307, score=1.00046968460083)
# Point(token_index=55, time_index=308, score=1.0006150007247925)
# Point(token_index=55, time_index=309, score=1.0034129619598389)
# Point(token_index=55, time_index=310, score=2.718151807785034)
# Point(token_index=55, time_index=311, score=2.7180233001708984)
# Point(token_index=55, time_index=312, score=2.7182509899139404)
# Point(token_index=56, time_index=313, score=2.7181994915008545)
# Point(token_index=56, time_index=314, score=2.7182769775390625)
# Point(token_index=56, time_index=315, score=2.7182791233062744)
# Point(token_index=56, time_index=316, score=2.718280792236328)
# Point(token_index=56, time_index=317, score=2.718280792236328)
# Point(token_index=56, time_index=318, score=2.7182815074920654)
# Point(token_index=56, time_index=319, score=2.7182815074920654)
# Point(token_index=56, time_index=320, score=2.7180867195129395)
# Point(token_index=57, time_index=321, score=1.6780179738998413)
# Point(token_index=57, time_index=322, score=2.7182772159576416)
# Point(token_index=57, time_index=323, score=2.7182791233062744)
# Point(token_index=57, time_index=324, score=2.7182745933532715)
# Point(token_index=57, time_index=325, score=2.718277931213379)
# Point(token_index=57, time_index=326, score=2.7182788848876953)
# Point(token_index=57, time_index=327, score=2.7180867195129395)
# Point(token_index=58, time_index=328, score=2.718263626098633)
# Point(token_index=58, time_index=329, score=2.718271017074585)
# Point(token_index=58, time_index=330, score=2.7182650566101074)
# Point(token_index=58, time_index=331, score=2.509587287902832)
# Point(token_index=58, time_index=332, score=1.1130287647247314)
# Point(token_index=58, time_index=333, score=1.3416794538497925)
# Point(token_index=58, time_index=334, score=1.2429746389389038)
# Point(token_index=58, time_index=335, score=2.5411109924316406)
# Point(token_index=58, time_index=336, score=2.71791672706604)
# Point(token_index=58, time_index=337, score=2.71692156791687)
# Point(token_index=58, time_index=338, score=2.7148008346557617)
# Point(token_index=58, time_index=339, score=2.7050702571868896)
# Point(token_index=58, time_index=340, score=2.6887643337249756)
# Point(token_index=58, time_index=341, score=2.7082598209381104)
# Point(token_index=58, time_index=342, score=2.678516149520874)
# Point(token_index=58, time_index=343, score=2.6679842472076416)
# Point(token_index=58, time_index=344, score=2.6076674461364746)
# Point(token_index=58, time_index=345, score=2.4468650817871094)
# Point(token_index=58, time_index=346, score=2.5171852111816406)
# Point(token_index=58, time_index=347, score=2.558511257171631)
# Point(token_index=58, time_index=348, score=1.800750970840454)
# Point(token_index=58, time_index=349, score=1.0321521759033203)
# Point(token_index=58, time_index=350, score=2.7145144939422607)
# Point(token_index=59, time_index=351, score=1.060268521308899)
# Point(token_index=59, time_index=352, score=2.703883647918701)
# Point(token_index=59, time_index=353, score=2.7182297706604004)
# Point(token_index=59, time_index=354, score=2.7182445526123047)
# Point(token_index=59, time_index=355, score=2.7182679176330566)
# Point(token_index=60, time_index=356, score=2.718248128890991)
# Point(token_index=60, time_index=357, score=2.718278169631958)
# Point(token_index=60, time_index=358, score=2.718273639678955)
# Point(token_index=60, time_index=359, score=2.718120813369751)
# Point(token_index=61, time_index=360, score=2.718156099319458)
# Point(token_index=61, time_index=361, score=1.0000112056732178)
# Point(token_index=62, time_index=362, score=1.561039686203003)
# Point(token_index=62, time_index=363, score=2.718210458755493)
# Point(token_index=63, time_index=364, score=2.7182013988494873)
# Point(token_index=64, time_index=365, score=2.718217372894287)
# Point(token_index=65, time_index=366, score=2.7111406326293945)
# Point(token_index=65, time_index=367, score=1.0017566680908203)
# Point(token_index=66, time_index=368, score=2.7182631492614746)
# Point(token_index=66, time_index=369, score=2.7182085514068604)
# Point(token_index=66, time_index=370, score=2.7182610034942627)
# Point(token_index=66, time_index=371, score=2.7182700634002686)
# Point(token_index=66, time_index=372, score=1.0848959684371948)
# Point(token_index=67, time_index=373, score=2.7182066440582275)
# Point(token_index=67, time_index=374, score=2.7180824279785156)
# Point(token_index=67, time_index=375, score=2.7167422771453857)
# Point(token_index=68, time_index=376, score=2.718223810195923)
# Point(token_index=68, time_index=377, score=2.713514566421509)
# Point(token_index=68, time_index=378, score=2.695880174636841)
# Point(token_index=69, time_index=379, score=2.717623710632324)
# Point(token_index=69, time_index=380, score=2.7178494930267334)
# Point(token_index=69, time_index=381, score=2.716780424118042)
# Point(token_index=69, time_index=382, score=2.7168171405792236)
# Point(token_index=69, time_index=383, score=2.7174558639526367)
# Point(token_index=69, time_index=384, score=2.715379238128662)
# Point(token_index=69, time_index=385, score=2.717625856399536)
# Point(token_index=70, time_index=386, score=2.712376356124878)
# Point(token_index=70, time_index=387, score=2.3208389282226562)
# Point(token_index=70, time_index=388, score=2.223900556564331)
# Point(token_index=70, time_index=389, score=2.130237579345703)
# Point(token_index=70, time_index=390, score=1.378212571144104)
# Point(token_index=70, time_index=391, score=2.63716983795166)
# Point(token_index=70, time_index=392, score=2.7072458267211914)
# Point(token_index=70, time_index=393, score=2.70705509185791)
# Point(token_index=70, time_index=394, score=2.6712865829467773)
# Point(token_index=70, time_index=395, score=2.4028618335723877)
# Point(token_index=70, time_index=396, score=1.8002727031707764)
# Point(token_index=70, time_index=397, score=1.9636796712875366)
# Point(token_index=70, time_index=398, score=2.273066520690918)
# Point(token_index=70, time_index=399, score=2.5843043327331543)
# Point(token_index=70, time_index=400, score=2.67978835105896)
# Point(token_index=70, time_index=401, score=2.7025530338287354)
# Point(token_index=70, time_index=402, score=2.7146284580230713)
# Point(token_index=70, time_index=403, score=2.7169370651245117)
# Point(token_index=70, time_index=404, score=2.7175815105438232)
# Point(token_index=70, time_index=405, score=2.718177080154419)
# Point(token_index=70, time_index=406, score=2.718275785446167)
# Point(token_index=70, time_index=407, score=2.718275308609009)
# Point(token_index=70, time_index=408, score=2.7182772159576416)
# Point(token_index=70, time_index=409, score=2.7182772159576416)
# Point(token_index=70, time_index=410, score=2.7182769775390625)
# Point(token_index=70, time_index=411, score=2.7182769775390625)
# Point(token_index=70, time_index=412, score=2.7182769775390625)
# Point(token_index=70, time_index=413, score=2.7178118228912354)
# Point(token_index=70, time_index=414, score=2.7179296016693115)
# Point(token_index=70, time_index=415, score=2.713853359222412)
# Point(token_index=70, time_index=416, score=2.7055346965789795)
# Point(token_index=70, time_index=417, score=2.714116096496582)
# Point(token_index=70, time_index=418, score=1.0000014305114746)

# %% [markdown]
# ## 9. Segment the path
#
# Now this path contains repetations for the same labels you can notice (token_index) as, so let’s merge them to make it close to the original transcript.
#
# When merging the multiple path points, we simply take the average probability for the merged segments.

# %%
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


segments = merge_repeats(path)
for seg in segments:
    print(seg)
# Out:
# ه	(2.67): [    0,    36)
# ذ	(2.72): [   36,    39)
# ا	(1.85): [   39,    43)
#  	(1.91): [   43,    47)
# ا	(2.32): [   47,    49)
# ل	(2.72): [   49,    53)
# ش	(2.72): [   53,    59)
# ا	(2.72): [   59,    63)
# ر	(2.44): [   63,    69)
# ع	(2.05): [   69,    72)
#  	(1.78): [   72,    80)
# س	(2.72): [   80,    87)
# و	(2.29): [   87,    91)
# ي	(1.00): [   91,    92)
#  	(2.68): [   92,    96)
# ل	(2.16): [   96,   103)
# م	(2.72): [  103,   108)
# م	(2.40): [  108,   113)
# ا	(2.72): [  113,   116)
# ر	(2.43): [  116,   122)
# س	(2.43): [  122,   128)
# ه	(1.94): [  128,   130)
#  	(1.70): [  130,   132)
# ر	(2.67): [  132,   136)
# ي	(2.72): [  136,   140)
# ا	(2.49): [  140,   144)
# ض	(2.43): [  144,   150)
# ه	(1.95): [  150,   153)
#  	(2.58): [  153,   156)
# ا	(1.59): [  156,   159)
# ل	(2.72): [  159,   161)
# ر	(2.66): [  161,   169)
# ك	(2.48): [  169,   176)
# ض	(2.21): [  176,   181)
#  	(2.15): [  181,   185)
# ي	(2.62): [  185,   190)
# و	(2.72): [  190,   194)
# م	(2.72): [  194,   200)
# ي	(2.55): [  200,   204)
# ا	(2.20): [  204,   222)
#  	(2.07): [  222,   226)
# و	(1.90): [  226,   228)
#  	(2.15): [  228,   231)
# ل	(2.72): [  231,   236)
# م	(2.15): [  236,   239)
#  	(1.49): [  239,   241)
# ا	(2.72): [  241,   246)
# ل	(2.72): [  246,   251)
# ت	(2.72): [  251,   259)
# ق	(2.37): [  259,   264)
# ي	(2.50): [  264,   283)
#  	(2.22): [  283,   288)
# ب	(2.48): [  288,   296)
# ا	(2.72): [  296,   302)
# ي	(2.72): [  302,   306)
#  	(1.74): [  306,   313)
# ش	(2.72): [  313,   321)
# خ	(2.57): [  321,   328)
# ص	(2.36): [  328,   351)
#  	(2.38): [  351,   356)
# ع	(2.72): [  356,   360)
# ل	(1.86): [  360,   362)
# ي	(2.14): [  362,   364)
#  	(2.72): [  364,   365)
# ا	(2.72): [  365,   366)
# ل	(1.86): [  366,   368)
# ا	(2.39): [  368,   373)
# ط	(2.72): [  373,   376)
# ل	(2.71): [  376,   379)
# ا	(2.72): [  379,   386)
# ق	(2.50): [  386,   419)

# %% [markdown]
# ## 10. Merge the segments into words
#
# Now let’s merge the words.
# Then, finally, we segment the original audio into segmented audio and listen to them to see if the segmentation is correct.

# %%
# Merge words
def merge_words(segments, separator=" "):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(segments)
for word in word_segments:
    print(word)
# Out:
# هذا	(2.59): [    0,    43)
# الشارع	(2.54): [   47,    72)
# سوي	(2.43): [   80,    92)
# لممارسه	(2.41): [   96,   130)
# رياضه	(2.47): [  132,   153)
# الركض	(2.40): [  156,   181)
# يوميا	(2.44): [  185,   222)
# و	(1.90): [  226,   228)
# لم	(2.50): [  231,   239)
# التقي	(2.58): [  241,   283)
# باي	(2.61): [  288,   306)
# شخص	(2.47): [  313,   351)
# علي	(2.36): [  356,   364)
# الاطلاق	(2.52): [  365,   419)

# %%
import IPython

def display_segment(i):
    ratio = waveform.size(1) / trellis.size(0)
    word = word_segments[i]
    x0 = int(ratio * word.start)
    x1 = int(ratio * word.end)
    print(f"{word.label} ({word.score:.2f}): {x0 / 16000:.3f} - {x1 / 16000:.3f} sec")
    segment = waveform[:, x0:x1]
    return IPython.display.Audio(segment.numpy(), rate=16000)

# %%
display_segment(0)
# Out:
# هذا (2.59): 0.000 - 0.862 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(1)
# Out:
# الشارع (2.54): 0.942 - 1.443 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(2)
# Out:
# سوي (2.43): 1.604 - 1.844 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display_segment(10)
# Out:
# باي (2.61): 5.774 - 6.135 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 11. Conclusion
#
# In this tutorial, you've learned how to:
#
# 1. Understand what force alignment is and why it's useful
# 2. Use wav2vec to perform word-level alignment on Arabic audio
# 3. Create an interactive visualization where you can click on words to hear them
#
# This technique can be applied to any language supported by wav2vec models and is useful for many applications including subtitling, language learning, and audio editing.
